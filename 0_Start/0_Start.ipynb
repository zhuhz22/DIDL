# %% [markdown]
# PyTorch has two primitives to work with data: torch.utils.data.DataLoader and torch.utils.data.Dataset. Dataset stores the samples and their corresponding labels, and DataLoader wraps an iterable around the Dataset.

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %% [markdown]
# PyTorch offers domain-specific libraries such as TorchText, TorchVision, and TorchAudio, all of which include datasets. For this tutorial, we will be using a TorchVision dataset.
#
# The torchvision.datasets module contains Dataset objects for many real-world vision data like CIFAR, COCO (full list here). In this tutorial, we use the FashionMNIST dataset. Every TorchVision Dataset includes two arguments: transform and target_transform to modify the samples and labels respectively.

# %%
# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %% [markdown]
# We pass the Dataset as an argument to DataLoader. This wraps an iterable over our dataset, and supports automatic batching, sampling, shuffling and multiprocess data loading. Here we define a batch size of 64, i.e. each element in the dataloader iterable will return a batch of 64 features and labels.<p>
# [batch_size参考](https://zhuanlan.zhihu.com/p/390341772)

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# To define a neural network in PyTorch, we create a class that inherits from nn.Module. We define the layers of the network in the __init__ function and specify how data will pass through the network in the forward function. To accelerate operations in the neural network, we move it to the GPU or MPS if available.

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cuda device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# To train a model, we need a loss function and an optimizer.<p>
# 损失函数和优化器

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %% [markdown]
# In a single training loop, the model makes predictions on the training dataset (fed to it in batches), and backpropagates the prediction error to adjust the model’s parameters.

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %% [markdown]
# We also check the model’s performance against the test dataset to ensure it is learning.

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %% [markdown]
# The training process is conducted over several iterations (epochs). During each epoch, the model learns parameters to make better predictions. We print the model’s accuracy and loss at each epoch; we’d like to see the accuracy increase and the loss decrease with every epoch.

# %%
epochs = 25
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.307054  [   64/60000]
# loss: 2.285305  [ 6464/60000]
# loss: 2.267751  [12864/60000]
# loss: 2.261125  [19264/60000]
# loss: 2.238482  [25664/60000]
# loss: 2.217485  [32064/60000]
# loss: 2.230013  [38464/60000]
# loss: 2.192685  [44864/60000]
# loss: 2.193852  [51264/60000]
# loss: 2.164988  [57664/60000]
# Test Error:
#  Accuracy: 43.0%, Avg loss: 2.149000
#
# Epoch 2
# -------------------------------
# loss: 2.163603  [   64/60000]
# loss: 2.145878  [ 6464/60000]
# loss: 2.087020  [12864/60000]
# loss: 2.107509  [19264/60000]
# loss: 2.047351  [25664/60000]
# loss: 1.994415  [32064/60000]
# loss: 2.029600  [38464/60000]
# loss: 1.944991  [44864/60000]
# loss: 1.959704  [51264/60000]
# loss: 1.884363  [57664/60000]
# Test Error:
#  Accuracy: 53.3%, Avg loss: 1.875022
#
# Epoch 3
# -------------------------------
# loss: 1.909076  [   64/60000]
# loss: 1.873346  [ 6464/60000]
# loss: 1.757634  [12864/60000]
# loss: 1.803462  [19264/60000]
# loss: 1.686897  [25664/60000]
# loss: 1.644302  [32064/60000]
# loss: 1.669654  [38464/60000]
# loss: 1.569997  [44864/60000]
# loss: 1.603465  [51264/60000]
# loss: 1.488592  [57664/60000]
# Test Error:
#  Accuracy: 61.3%, Avg loss: 1.508981
#
# Epoch 4
# -------------------------------
# loss: 1.578726  [   64/60000]
# loss: 1.542390  [ 6464/60000]
# loss: 1.393399  [12864/60000]
# loss: 1.461805  [19264/60000]
# loss: 1.342457  [25664/60000]
# loss: 1.342590  [32064/60000]
# loss: 1.355645  [38464/60000]
# loss: 1.284627  [44864/60000]
# loss: 1.324867  [51264/60000]
# loss: 1.213865  [57664/60000]
# Test Error:
#  Accuracy: 63.1%, Avg loss: 1.245007
#
# Epoch 5
# -------------------------------
# loss: 1.326393  [   64/60000]
# loss: 1.308555  [ 6464/60000]
# loss: 1.141820  [12864/60000]
# loss: 1.242983  [19264/60000]
# loss: 1.116443  [25664/60000]
# loss: 1.145229  [32064/60000]
# loss: 1.166373  [38464/60000]
# loss: 1.107526  [44864/60000]
# loss: 1.153084  [51264/60000]
# loss: 1.057222  [57664/60000]
# Test Error:
#  Accuracy: 64.4%, Avg loss: 1.082552
#
# Epoch 6
# -------------------------------
# loss: 1.158812  [   64/60000]
# loss: 1.161015  [ 6464/60000]
# loss: 0.977090  [12864/60000]
# loss: 1.108364  [19264/60000]
# loss: 0.979105  [25664/60000]
# loss: 1.013716  [32064/60000]
# loss: 1.051280  [38464/60000]
# loss: 0.994858  [44864/60000]
# loss: 1.042272  [51264/60000]
# loss: 0.960493  [57664/60000]
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.978634
#
# Epoch 7
# -------------------------------
# loss: 1.043241  [   64/60000]
# loss: 1.065916  [ 6464/60000]
# loss: 0.865227  [12864/60000]
# loss: 1.019531  [19264/60000]
# loss: 0.894008  [25664/60000]
# loss: 0.922157  [32064/60000]
# loss: 0.977187  [38464/60000]
# loss: 0.921606  [44864/60000]
# loss: 0.966012  [51264/60000]
# loss: 0.896179  [57664/60000]
# Test Error:
#  Accuracy: 66.6%, Avg loss: 0.908307
#
# Epoch 8
# -------------------------------
# loss: 0.958554  [   64/60000]
# loss: 0.999754  [ 6464/60000]
# loss: 0.786117  [12864/60000]
# loss: 0.956814  [19264/60000]
# loss: 0.838017  [25664/60000]
# loss: 0.855764  [32064/60000]
# loss: 0.925634  [38464/60000]
# loss: 0.872432  [44864/60000]
# loss: 0.910968  [51264/60000]
# loss: 0.849870  [57664/60000]
# Test Error:
#  Accuracy: 68.0%, Avg loss: 0.857861
#
# Epoch 9
# -------------------------------
# loss: 0.893641  [   64/60000]
# loss: 0.950175  [ 6464/60000]
# loss: 0.727376  [12864/60000]
# loss: 0.909844  [19264/60000]
# loss: 0.798742  [25664/60000]
# loss: 0.805794  [32064/60000]
# loss: 0.886756  [38464/60000]
# loss: 0.838016  [44864/60000]
# loss: 0.869700  [51264/60000]
# loss: 0.814546  [57664/60000]
# Test Error:
#  Accuracy: 69.0%, Avg loss: 0.819628
#
# Epoch 10
# -------------------------------
# loss: 0.841673  [   64/60000]
# loss: 0.910368  [ 6464/60000]
# loss: 0.681735  [12864/60000]
# loss: 0.873286  [19264/60000]
# loss: 0.769379  [25664/60000]
# loss: 0.767336  [32064/60000]
# loss: 0.855396  [38464/60000]
# loss: 0.812530  [44864/60000]
# loss: 0.837451  [51264/60000]
# loss: 0.786051  [57664/60000]
# Test Error:
#  Accuracy: 70.3%, Avg loss: 0.789168
#
# Epoch 11
# -------------------------------
# loss: 0.798515  [   64/60000]
# loss: 0.876593  [ 6464/60000]
# loss: 0.644760  [12864/60000]
# loss: 0.843934  [19264/60000]
# loss: 0.745884  [25664/60000]
# loss: 0.736751  [32064/60000]
# loss: 0.828673  [38464/60000]
# loss: 0.792488  [44864/60000]
# loss: 0.811319  [51264/60000]
# loss: 0.761835  [57664/60000]
# Test Error:
#  Accuracy: 71.5%, Avg loss: 0.763724
#
# Epoch 12
# -------------------------------
# loss: 0.761418  [   64/60000]
# loss: 0.846803  [ 6464/60000]
# loss: 0.613669  [12864/60000]
# loss: 0.819759  [19264/60000]
# loss: 0.726087  [25664/60000]
# loss: 0.711988  [32064/60000]
# loss: 0.804624  [38464/60000]
# loss: 0.775825  [44864/60000]
# loss: 0.789436  [51264/60000]
# loss: 0.740627  [57664/60000]
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.741698
#
# Epoch 13
# -------------------------------
# loss: 0.728880  [   64/60000]
# loss: 0.819753  [ 6464/60000]
# loss: 0.586927  [12864/60000]
# loss: 0.799249  [19264/60000]
# loss: 0.708894  [25664/60000]
# loss: 0.691271  [32064/60000]
# loss: 0.782407  [38464/60000]
# loss: 0.761131  [44864/60000]
# loss: 0.770520  [51264/60000]
# loss: 0.721575  [57664/60000]
# Test Error:
#  Accuracy: 73.9%, Avg loss: 0.722058
#
# Epoch 14
# -------------------------------
# loss: 0.700020  [   64/60000]
# loss: 0.795055  [ 6464/60000]
# loss: 0.563483  [12864/60000]
# loss: 0.781424  [19264/60000]
# loss: 0.693827  [25664/60000]
# loss: 0.673615  [32064/60000]
# loss: 0.761696  [38464/60000]
# loss: 0.747892  [44864/60000]
# loss: 0.753887  [51264/60000]
# loss: 0.704121  [57664/60000]
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.704204
#
# Epoch 15
# -------------------------------
# loss: 0.674024  [   64/60000]
# loss: 0.772221  [ 6464/60000]
# loss: 0.542607  [12864/60000]
# loss: 0.765619  [19264/60000]
# loss: 0.680290  [25664/60000]
# loss: 0.658468  [32064/60000]
# loss: 0.742177  [38464/60000]
# loss: 0.735676  [44864/60000]
# loss: 0.739120  [51264/60000]
# loss: 0.687957  [57664/60000]
# Test Error:
#  Accuracy: 75.5%, Avg loss: 0.687797
#
# Epoch 16
# -------------------------------
# loss: 0.650534  [   64/60000]
# loss: 0.750993  [ 6464/60000]
# loss: 0.523952  [12864/60000]
# loss: 0.751481  [19264/60000]
# loss: 0.668169  [25664/60000]
# loss: 0.645282  [32064/60000]
# loss: 0.723734  [38464/60000]
# loss: 0.724534  [44864/60000]
# loss: 0.725957  [51264/60000]
# loss: 0.672899  [57664/60000]
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.672636
#
# Epoch 17
# -------------------------------
# loss: 0.629327  [   64/60000]
# loss: 0.731337  [ 6464/60000]
# loss: 0.507227  [12864/60000]
# loss: 0.738635  [19264/60000]
# loss: 0.657261  [25664/60000]
# loss: 0.633600  [32064/60000]
# loss: 0.706402  [38464/60000]
# loss: 0.714490  [44864/60000]
# loss: 0.714307  [51264/60000]
# loss: 0.658734  [57664/60000]
# Test Error:
#  Accuracy: 76.8%, Avg loss: 0.658603
#
# Epoch 18
# -------------------------------
# loss: 0.610104  [   64/60000]
# loss: 0.713171  [ 6464/60000]
# loss: 0.492145  [12864/60000]
# loss: 0.726877  [19264/60000]
# loss: 0.647515  [25664/60000]
# loss: 0.623213  [32064/60000]
# loss: 0.690086  [38464/60000]
# loss: 0.705583  [44864/60000]
# loss: 0.704022  [51264/60000]
# loss: 0.645420  [57664/60000]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.645619
#
# Epoch 19
# -------------------------------
# loss: 0.592644  [   64/60000]
# loss: 0.696319  [ 6464/60000]
# loss: 0.478566  [12864/60000]
# loss: 0.716036  [19264/60000]
# loss: 0.638770  [25664/60000]
# loss: 0.613975  [32064/60000]
# loss: 0.674734  [38464/60000]
# loss: 0.697726  [44864/60000]
# loss: 0.694973  [51264/60000]
# loss: 0.632896  [57664/60000]
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.633632
#
# Epoch 20
# -------------------------------
# loss: 0.576767  [   64/60000]
# loss: 0.680785  [ 6464/60000]
# loss: 0.466260  [12864/60000]
# loss: 0.706094  [19264/60000]
# loss: 0.630845  [25664/60000]
# loss: 0.605580  [32064/60000]
# loss: 0.660393  [38464/60000]
# loss: 0.690963  [44864/60000]
# loss: 0.687014  [51264/60000]
# loss: 0.621029  [57664/60000]
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.622580
#
# Epoch 21
# -------------------------------
# loss: 0.562202  [   64/60000]
# loss: 0.666453  [ 6464/60000]
# loss: 0.455046  [12864/60000]
# loss: 0.696884  [19264/60000]
# loss: 0.623478  [25664/60000]
# loss: 0.597987  [32064/60000]
# loss: 0.647001  [38464/60000]
# loss: 0.685277  [44864/60000]
# loss: 0.680108  [51264/60000]
# loss: 0.609703  [57664/60000]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.612402
#
# Epoch 22
# -------------------------------
# loss: 0.548769  [   64/60000]
# loss: 0.653278  [ 6464/60000]
# loss: 0.444767  [12864/60000]
# loss: 0.688269  [19264/60000]
# loss: 0.616616  [25664/60000]
# loss: 0.591085  [32064/60000]
# loss: 0.634471  [38464/60000]
# loss: 0.680642  [44864/60000]
# loss: 0.674179  [51264/60000]
# loss: 0.598897  [57664/60000]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.603026
#
# Epoch 23
# -------------------------------
# loss: 0.536340  [   64/60000]
# loss: 0.641115  [ 6464/60000]
# loss: 0.435328  [12864/60000]
# loss: 0.680269  [19264/60000]
# loss: 0.610207  [25664/60000]
# loss: 0.584696  [32064/60000]
# loss: 0.622845  [38464/60000]
# loss: 0.676975  [44864/60000]
# loss: 0.669139  [51264/60000]
# loss: 0.588578  [57664/60000]
# Test Error:
#  Accuracy: 79.2%, Avg loss: 0.594388
#
# Epoch 24
# -------------------------------
# loss: 0.524814  [   64/60000]
# loss: 0.629835  [ 6464/60000]
# loss: 0.426641  [12864/60000]
# loss: 0.672750  [19264/60000]
# loss: 0.604067  [25664/60000]
# loss: 0.578737  [32064/60000]
# loss: 0.612015  [38464/60000]
# loss: 0.674090  [44864/60000]
# loss: 0.664816  [51264/60000]
# loss: 0.578694  [57664/60000]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.586418
#
# Epoch 25
# -------------------------------
# loss: 0.514038  [   64/60000]
# loss: 0.619419  [ 6464/60000]
# loss: 0.418602  [12864/60000]
# loss: 0.665634  [19264/60000]
# loss: 0.598103  [25664/60000]
# loss: 0.573113  [32064/60000]
# loss: 0.601903  [38464/60000]
# loss: 0.671902  [44864/60000]
# loss: 0.661144  [51264/60000]
# loss: 0.569134  [57664/60000]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.579048
#
# Done!

# %% [markdown]
# A common way to save a model is to serialize the internal state dictionary (containing the model parameters).

# %%
torch.save(model.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %% [markdown]
# The process for loading a model includes re-creating the model structure and loading the state dictionary into it.

# %%
model = NeuralNetwork().to(device)
model.load_state_dict(torch.load("model.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# This model can now be used to make predictions.

# %%
classes = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot",
]

model.eval()
cnt=0
for _ in range(100):
    print(f"Case{str(_)}")
    x, y = test_data[_][0], test_data[_][1]
    with torch.no_grad():
        x = x.to(device)
        pred = model(x)
        predicted, actual = classes[pred[0].argmax(0)], classes[y]
        print(f'Predicted: "{predicted}", Actual: "{actual}"')
        if predicted==actual:
            print("Succeed!")
            cnt+=1
        else:
            print("Failed!")
print(f"Accuracy: {str(cnt)}%")
# Out:
# Case0
# Predicted: "Ankle boot", Actual: "Ankle boot"
# Succeed!
# Case1
# Predicted: "Pullover", Actual: "Pullover"
# Succeed!
# Case2
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case3
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case4
# Predicted: "Shirt", Actual: "Shirt"
# Succeed!
# Case5
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case6
# Predicted: "Coat", Actual: "Coat"
# Succeed!
# Case7
# Predicted: "Shirt", Actual: "Shirt"
# Succeed!
# Case8
# Predicted: "Sandal", Actual: "Sandal"
# Succeed!
# Case9
# Predicted: "Sneaker", Actual: "Sneaker"
# Succeed!
# Case10
# Predicted: "Coat", Actual: "Coat"
# Succeed!
# Case11
# Predicted: "Sandal", Actual: "Sandal"
# Succeed!
# Case12
# Predicted: "Sandal", Actual: "Sneaker"
# Failed!
# Case13
# Predicted: "Dress", Actual: "Dress"
# Succeed!
# Case14
# Predicted: "Coat", Actual: "Coat"
# Succeed!
# Case15
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case16
# Predicted: "Pullover", Actual: "Pullover"
# Succeed!
# Case17
# Predicted: "Shirt", Actual: "Coat"
# Failed!
# Case18
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case19
# Predicted: "T-shirt/top", Actual: "T-shirt/top"
# Succeed!
# Case20
# Predicted: "T-shirt/top", Actual: "Pullover"
# Failed!
# Case21
# Predicted: "Sneaker", Actual: "Sandal"
# Failed!
# Case22
# Predicted: "Sneaker", Actual: "Sneaker"
# Succeed!
# Case23
# Predicted: "Sneaker", Actual: "Ankle boot"
# Failed!
# Case24
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case25
# Predicted: "Pullover", Actual: "Coat"
# Failed!
# Case26
# Predicted: "Coat", Actual: "Shirt"
# Failed!
# Case27
# Predicted: "Dress", Actual: "T-shirt/top"
# Failed!
# Case28
# Predicted: "Ankle boot", Actual: "Ankle boot"
# Succeed!
# Case29
# Predicted: "Coat", Actual: "Dress"
# Failed!
# Case30
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case31
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case32
# Predicted: "Dress", Actual: "Dress"
# Succeed!
# Case33
# Predicted: "Dress", Actual: "Dress"
# Succeed!
# Case34
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case35
# Predicted: "T-shirt/top", Actual: "T-shirt/top"
# Succeed!
# Case36
# Predicted: "Sneaker", Actual: "Sneaker"
# Succeed!
# Case37
# Predicted: "Sandal", Actual: "Sandal"
# Succeed!
# Case38
# Predicted: "Sneaker", Actual: "Sneaker"
# Succeed!
# Case39
# Predicted: "Ankle boot", Actual: "Ankle boot"
# Succeed!
# Case40
# Predicted: "T-shirt/top", Actual: "Shirt"
# Failed!
# Case41
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case42
# Predicted: "Shirt", Actual: "Dress"
# Failed!
# Case43
# Predicted: "Ankle boot", Actual: "Sneaker"
# Failed!
# Case44
# Predicted: "Shirt", Actual: "Shirt"
# Succeed!
# Case45
# Predicted: "Ankle boot", Actual: "Sneaker"
# Failed!
# Case46
# Predicted: "Pullover", Actual: "Pullover"
# Succeed!
# Case47
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case48
# Predicted: "Coat", Actual: "Pullover"
# Failed!
# Case49
# Predicted: "Shirt", Actual: "Pullover"
# Failed!
# Case50
# Predicted: "Shirt", Actual: "Coat"
# Failed!
# Case51
# Predicted: "Pullover", Actual: "Coat"
# Failed!
# Case52
# Predicted: "Sandal", Actual: "Sandal"
# Succeed!
# Case53
# Predicted: "Shirt", Actual: "Bag"
# Failed!
# Case54
# Predicted: "Coat", Actual: "Pullover"
# Failed!
# Case55
# Predicted: "Pullover", Actual: "Pullover"
# Succeed!
# Case56
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case57
# Predicted: "Coat", Actual: "Coat"
# Succeed!
# Case58
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case59
# Predicted: "T-shirt/top", Actual: "T-shirt/top"
# Succeed!
# Case60
# Predicted: "Sneaker", Actual: "Sneaker"
# Succeed!
# Case61
# Predicted: "Sneaker", Actual: "Sneaker"
# Succeed!
# Case62
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case63
# Predicted: "Sandal", Actual: "Sandal"
# Succeed!
# Case64
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case65
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case66
# Predicted: "Dress", Actual: "Pullover"
# Failed!
# Case67
# Predicted: "Coat", Actual: "Dress"
# Failed!
# Case68
# Predicted: "Sneaker", Actual: "Ankle boot"
# Failed!
# Case69
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case70
# Predicted: "Sneaker", Actual: "Sneaker"
# Succeed!
# Case71
# Predicted: "T-shirt/top", Actual: "T-shirt/top"
# Succeed!
# Case72
# Predicted: "Shirt", Actual: "Pullover"
# Failed!
# Case73
# Predicted: "Shirt", Actual: "Shirt"
# Succeed!
# Case74
# Predicted: "Coat", Actual: "Pullover"
# Failed!
# Case75
# Predicted: "Dress", Actual: "Dress"
# Succeed!
# Case76
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case77
# Predicted: "Pullover", Actual: "Pullover"
# Succeed!
# Case78
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case79
# Predicted: "Coat", Actual: "Coat"
# Succeed!
# Case80
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case81
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case82
# Predicted: "Sandal", Actual: "Sandal"
# Succeed!
# Case83
# Predicted: "Ankle boot", Actual: "Ankle boot"
# Succeed!
# Case84
# Predicted: "Sandal", Actual: "Sandal"
# Succeed!
# Case85
# Predicted: "T-shirt/top", Actual: "T-shirt/top"
# Succeed!
# Case86
# Predicted: "Dress", Actual: "Dress"
# Succeed!
# Case87
# Predicted: "Shirt", Actual: "Pullover"
# Failed!
# Case88
# Predicted: "T-shirt/top", Actual: "T-shirt/top"
# Succeed!
# Case89
# Predicted: "Shirt", Actual: "Shirt"
# Succeed!
# Case90
# Predicted: "Sandal", Actual: "Sandal"
# Succeed!
# Case91
# Predicted: "Dress", Actual: "Dress"
# Succeed!
# Case92
# Predicted: "Shirt", Actual: "Shirt"
# Succeed!
# Case93
# Predicted: "Sneaker", Actual: "Sneaker"
# Succeed!
# Case94
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case95
# Predicted: "Bag", Actual: "Bag"
# Succeed!
# Case96
# Predicted: "T-shirt/top", Actual: "T-shirt/top"
# Succeed!
# Case97
# Predicted: "Trouser", Actual: "Trouser"
# Succeed!
# Case98
# Predicted: "Shirt", Actual: "Coat"
# Failed!
# Case99
# Predicted: "Pullover", Actual: "Pullover"
# Succeed!
# Accuracy: 74%
